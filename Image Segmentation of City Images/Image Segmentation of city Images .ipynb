# %% [markdown]
# ## Image segmentation with CamVid

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# ...
# [PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/images'),
#  PosixPath('/root/.fastai/data/camvid/labels'),
#  PosixPath('/root/.fastai/data/camvid/codes.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0001TP_009360.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f00960.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_05940.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/0016E5_07380_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/Seq05VD_f00930_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_08061_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[21, 21, 21,  ..., 26, 26, 26],
#           [21, 21, 21,  ..., 26, 26, 26],
#           [21, 21, 21,  ..., 26, 26, 26],
#           ...,
#           [19, 19, 19,  ..., 30, 30, 30],
#           [19, 19, 19,  ..., 30, 30, 30],
#           [19, 19, 19,  ..., 30, 30, 30]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2  #u are literally creating a classifier for every pixel so a smaller batch size is definitely recommended.

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes)) #over here the validation set is not created at random. we are explicitely mentioning which to take as the validation set. since these are frames of images. we have already been provided with the validation set folder along with dataset by the people who made this dataset.

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True) #tfm_y=True means that whatever transform you are doing on x, do that on y as well where y and x are dependant and indeendant variable respectable.
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)# for segmentation an architecture called unet works better.
#check 1hr 31min for how to do mixed precision training. it can help to do faster also and use less GPU RAM.
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.316301</td>
#       <td>0.910023</td>
#       <td>0.788607</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.864306</td>
#       <td>0.654819</td>
#       <td>0.837024</td>
#       <td>03:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.712941</td>
#       <td>0.496946</td>
#       <td>0.864829</td>
#       <td>03:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.640878</td>
#       <td>0.466830</td>
#       <td>0.871595</td>
#       <td>03:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.618035</td>
#       <td>0.468403</td>
#       <td>0.861647</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lrs = slice(1e-05,1e-03)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.382084</td>
#       <td>0.318820</td>
#       <td>0.904730</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.372434</td>
#       <td>0.309813</td>
#       <td>0.907637</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.362654</td>
#       <td>0.318490</td>
#       <td>0.904366</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.349832</td>
#       <td>0.305334</td>
#       <td>0.912246</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.343053</td>
#       <td>0.303218</td>
#       <td>0.912041</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_lr()#from the below graph we can see that the fit_one_cycle makes the learning rate start low, go up and then go down again. 
#check 1hr:21 for details.

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size#over here we want to segment all of the pixels.not half of the pixels unlike before.

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=4
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6cae40b97b5> in <module>()
# ----> 1 learn.destroy()
#       2
#       3 size = src_size#over here we want to segment all of the pixels.not half of the pixels unlike before.
#       4
#       5 free = gpu_mem_get_free_no_cache()
#
# NameError: name 'learn' is not defined

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');#this leaner now has the same weights as stage 2 one.

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=1e-3

# %%
doc(learn.fit_one_cycle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f8c549491353> in <module>()
# ----> 1 doc(learn.fit_one_cycle)
#
# NameError: name 'learn' is not defined

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# Total time: 20:31 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.366140</th>
#     <th>0.339497</th>
#     <th>0.908682</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.333278</th>
#     <th>0.304011</th>
#     <th>0.916702</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.326025</th>
#     <th>0.305404</th>
#     <th>0.919941</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.336885</th>
#     <th>0.321342</th>
#     <th>0.910933</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.326935</th>
#     <th>0.305589</th>
#     <th>0.919401</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.347779</th>
#     <th>0.333608</th>
#     <th>0.908895</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.328334</th>
#     <th>0.352358</th>
#     <th>0.905482</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.327277</th>
# ...

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# Total time: 21:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.225999</th>
#     <th>0.254650</th>
#     <th>0.930782</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.216341</th>
#     <th>0.256007</th>
#     <th>0.930751</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.209800</th>
#     <th>0.255649</th>
#     <th>0.930709</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.203509</th>
#     <th>0.252857</th>
#     <th>0.931682</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.202308</th>
#     <th>0.258498</th>
#     <th>0.931308</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.200796</th>
#     <th>0.257311</th>
#     <th>0.931915</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.204560</th>
#     <th>0.251486</th>
#     <th>0.933218</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.192893</th>
# ...

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
